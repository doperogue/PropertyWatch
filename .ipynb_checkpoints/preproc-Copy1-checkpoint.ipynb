# %%
#importing libraries
import pandas as pd
import numpy as np
import re

# %%
#import the csv file
data = pd.read_csv('housedata.csv')

# %%
completed_frame = data

# %%
#replace missing values by mean
for i in data.columns:
    j=data[i].mode()
    completed_frame = completed_frame.replace({i:np.NaN},j[0])

# %%
completed_frame
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
local = list(completed_frame.iloc[:,4])

# %%
for i in range(len(local)):
    if 'Chittaranjan Park' in local[i]:
        local[i] = 'Chittaranjan Park'

# %%
m = re.findall(r'Rohini Sector \d+' , local[14])

# %%
m[0]
# Out:
# 'Rohini Sector 8'

# %%
for i in range(len(local)):
    k=re.findall(r'Dwarka Sector \d+' , local[i])
    if len(k)!=0:
        local[i] = k[0]

# %%
locality_list1 =[]
for i in local:
    if len(i) < 84:
        locality_list1.append(i)

# %%
len('DLF Capital Greens, Moti Nagar, Kirti Nagar ( 1 km from New Moti Nagar, Kirti Nagar)')
# Out:
# 84

# %%
locality_list1
# Out:
# ['Rohini Sector 25',
#  'Rohini Sector 24',
#  'Rohini Sector 13',
#  'Rohini Sector 24',
#  'Rohini Sector 24',
#  'Rohini Sector 24',
#  'Rohini Sector 24',
#  'Rohini Sector 24',
#  'Rohini Sector 21',
#  'Rohini Sector 22',
#  'Rohini Sector 20',
#  'Rohini Sector 25',
#  'Rohini Sector 24',
#  'Rohini Sector 24',
#  'Rohini Sector 8',
#  'Rohini Sector 25',
#  'Rohini Sector 22',
#  'Rohini Sector 16',
#  'Rohini Sector 14',
#  'Rohini Sector 24',
#  'Rohini Sector 9',
#  'Vijay Vihar, Rohini',
#  'Rohini Sector 18',
#  'Prashant Vihar, Rohini',
#  'Rohini Sector 5',
#  'Rohini Sector 20',
#  'Rohini Sector 25',
#  'Rohini Sector 28',
#  'Rohini Sector 25',
#  'Rohini Sector 19',
#  'Lajpat Nagar 2',
#  'Lajpat Nagar 1',
#  'Lajpat Nagar',
#  'Vikram Vihar, Lajpat Nagar',
#  'Lajpat Nagar 4',
#  'Lajpat Nagar 3',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar 2',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar 3',
#  'Lajpat Nagar 4',
# ...

# %%
locality_list0 = pd.DataFrame(locality_list1)

# %%
len(pd.unique(locality_list0[0]))
# Out:
# 312

# %%
for i in local:
    print(i)
# Out:
# Rohini Sector 25
# Rohini Sector 24
# Rohini Sector 13
# Rohini Sector 24
# Rohini Sector 24
# Rohini Sector 24
# Rohini Sector 24
# Rohini Sector 24
# Rohini Sector 21
# Rohini Sector 22
# Rohini Sector 20
# Rohini Sector 25
# Rohini Sector 24
# Rohini Sector 24
# Rohini Sector 8
# Rohini Sector 25
# Rohini Sector 22
# Rohini Sector 16
# Rohini Sector 14
# Rohini Sector 24
# Rohini Sector 9
# Vijay Vihar, Rohini
# Rohini Sector 18
# Prashant Vihar, Rohini
# Rohini Sector 5
# Rohini Sector 20
# Rohini Sector 25
# Rohini Sector 28
# Rohini Sector 25
# Rohini Sector 19
# Lajpat Nagar 2
# Lajpat Nagar 1
# Lajpat Nagar
# Vikram Vihar, Lajpat Nagar
# Lajpat Nagar 4
# Lajpat Nagar 3
# Lajpat Nagar
# ...

# %%
completed_frame[completed_frame['Parking']==39]
# Out:
#       Area  BHK  Bathroom      Furnishing                    Locality  \
# 875  365.0    1       1.0     Unfurnished                      Narela
# 876  390.0    1       1.0     Unfurnished       DDA Lig Flats, Narela
# 877  350.0    1       1.0     Unfurnished  DDA Flats Pocket 3, Narela
# 878  210.0    1       1.0  Semi-Furnished       DDA Lig Flats, Narela
# 879   50.0    1       1.0     Unfurnished       DDA Lig Flats, Narela
# 880  500.0    1       1.0     Unfurnished        DDA Pocket H, Narela
# 881  350.0    1       1.0     Unfurnished       DDA Lig Flats, Narela
#
#      Parking    Price         Status   Transaction       Type  Per_Sqft
# 875     39.0  3500000  Ready_to_move        Resale  Apartment    7143.0
# 876     39.0  2000000  Ready_to_move        Resale  Apartment    5128.0
# 877     39.0  3000000  Ready_to_move        Resale  Apartment    5128.0
# 878     39.0  2000000  Ready_to_move  New_Property  Apartment    5128.0
# ...

# %%
import seaborn as sns

# %%
sns.countplot(completed_frame_demo['Locality'])

# %%
final_l = ['Rohini' , 'Lajpat Nagar', 'Dwarka', 'Budh Vihar', 'Patel Nagar', 'Uttam Nagar', 'Greater Kailash', 'Okhla'
           ,'New Friends Colony','Shahdara','Laxmi Nagar','Vasant Kunj','Geeta Colony','Saket','Safdarjung','Paschim Vihar'
           ,'Commonwealth Games Village','Alaknanda','Sultanpur','Sarita Vihar','Chhattarpur','Mehrauli','Mahavir'
           ,'Narela','Malviya Nagar','Dilshad Garden','Vasundhara','Karol Bagh','Kirti Nagar','Sheikh Sarai','Punjabi Bagh'
           ,'Kalkaji','Hauz Khas' , 'Chittaranjan Park']

# %%
len(final_l)
# Out:
# 34

# %%
for j in final_l:  
    for i in range(len(local)):
        k=re.findall(r''+re.escape(j)+'' , local[i])
        if len(k)!=0:
            local[i] = k[0]

# %%
local
# Out:
# ['Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Rohini',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Lajpat Nagar',
#  'Dwarka',
#  'Dwarka',
#  'Dwarka',
# ...

# %%
len(local)
# Out:
# 1259

# %%
fi = pd.DataFrame(local)

# %%
ni = list(pd.unique(fi[0]))

# %%
completed_frame['Locality'] = local

# %%
completed_frame
# Out:
#          Area  BHK  Bathroom      Furnishing           Locality  Parking  \
# 0       800.0    3       2.0  Semi-Furnished             Rohini      1.0
# 1       750.0    2       2.0  Semi-Furnished             Rohini      1.0
# 2       950.0    2       2.0       Furnished             Rohini      1.0
# 3       600.0    2       2.0  Semi-Furnished             Rohini      1.0
# 4       650.0    2       2.0  Semi-Furnished             Rohini      1.0
# ...       ...  ...       ...             ...                ...      ...
# 1254   4118.0    4       5.0     Unfurnished  Chittaranjan Park      3.0
# 1255   1050.0    3       2.0  Semi-Furnished  Chittaranjan Park      3.0
# 1256    875.0    3       3.0  Semi-Furnished  Chittaranjan Park      3.0
# 1257    990.0    2       2.0     Unfurnished  Chittaranjan Park      1.0
# 1258  11050.0    3       3.0     Unfurnished  Chittaranjan Park      1.0
#
#          Price         Status   Transaction           Type  Per_Sqft
# ...

# %%
garbage_local = list(set(ni) - set(final_l))

# %%
completed_frame_demo = completed_frame_demo.replace({'Locality':garbage_local},'garbage')

# %%
len(pd.unique(completed_frame_demo['Locality']))
# Out:
# 35

# %%
completed_frame_demo.to_csv('final.csv' , index = False)

# %%
demo = pd.get_dummies(completed_frame_demo,drop_first=True)

# %%
demo = completed_frame_demo[completed_frame_demo['Locality']!= 'garbage']

# %%
demo = pd.get_dummies(demo,drop_first=True)

# %%
demo
# Out:
#          Area  BHK  Bathroom  Parking     Price  Per_Sqft  \
# 0       800.0    3       2.0      1.0   6500000   12500.0
# 1       750.0    2       2.0      1.0   5000000    6667.0
# 2       950.0    2       2.0      1.0  15500000    6667.0
# 3       600.0    2       2.0      1.0   4200000    6667.0
# 4       650.0    2       2.0      1.0   6200000    6667.0
# ...       ...  ...       ...      ...       ...       ...
# 1254   4118.0    4       5.0      3.0  55000000   12916.0
# 1255   1050.0    3       2.0      3.0  12500000   12916.0
# 1256    875.0    3       3.0      3.0  17500000   12916.0
# 1257    990.0    2       2.0      1.0  11500000   12916.0
# 1258  11050.0    3       3.0      1.0  18500000   12916.0
#
#       Furnishing_Semi-Furnished  Furnishing_Unfurnished  Locality_Budh Vihar  \
# 0                             1                       0                    0
# 1                             1                       0                    0
# ...

# %%
demo.to_csv('final_with_dummies.csv', index = False)
